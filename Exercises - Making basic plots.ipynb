# %% [markdown]
# # Exercise 1
#
# Create a line plot showing the number of marriages and divorces per capita in the U.S. between 1867 and 2014. Label both of the lines and show the legend.
#
# Don't forget to label your axes!
#
# **Bonus:** Use the ggplot style.

# %%
import pandas as pd

us_marriage_divorce_data = pd.read_csv('data/us-marriages-divorces-1867-2014.csv')
years = us_marriage_divorce_data['Year'].values
marriages_per_capita = us_marriage_divorce_data['Marriages_per_1000'].values
divorces_per_capita = us_marriage_divorce_data['Divorces_per_1000'].values

#import matplotlib and numpy
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

#import the data
x = years
y1 = marriages_per_capita
y2 = divorces_per_capita

#create the plot
plt.figure(figsize=(10,10))
plt.plot(x,
         y1,
         color='red',
         linestyle='-',
         linewidth=1,
         marker='s',
         markersize=3,
         label='Marriages per capita')

plt.plot(x,
         y2,
         color='gray',
         linestyle='--',
         linewidth=1,
         marker='^',
         markersize=3,
         label='Divorces per capita')

plt.legend()
;
# Out:
# ''

# %% [markdown]
# # Exercise 2
#
# Create a vertical bar chart comparing the number of marriages and divorces per capita in the U.S. between 1900, 1950, and 2000.
#
# Don't forget to label your axes!

# %%
import pandas as pd
us_marriage_divorce_data = pd.read_csv('data/us-marriages-divorces-1867-2014.csv')
us_marriage_divorce_data = us_marriage_divorce_data[
    us_marriage_divorce_data['Year'].apply(lambda x: x in [1900, 1950, 2000])]

years = us_marriage_divorce_data['Year'].values
marriages_per_capita = us_marriage_divorce_data['Marriages_per_1000'].values
divorces_per_capita = us_marriage_divorce_data['Divorces_per_1000'].values

#import matplotlib and numpy
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# values = [marriages_per_capita, divorces_per_capita]

plt.figure(figsize=(10,5)

plt.bar(years, marriages_per_capita,divorces_per_capita )
plt.bar(years + 2,
        marriages_per_capita,
        color='blue',
        edgecolor='none',
        width=4,
        align='center',
        label='Marriages %')

plt.bar(years - 2,
        divorces_per_capita,
        color = 'orange',
        edgecolor='none',
        width=4,
        align='center',
        label='Divorces %')

plt.xticks(years, [str(year) for year in years])

plt.legend()
;
# Out:
#   File "<ipython-input-4-549a6058e49a>", line 19
#     plt.bar(years, marriages_per_capita,divorces_per_capita )
#       ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
us_marriage_divorce_data = pd.read_csv('data/us-marriages-divorces-1867-2014.csv')


years = us_marriage_divorce_data['Year'].values
marriages_per_capita = us_marriage_divorce_data['Marriages_per_1000'].values
divorces_per_capita = us_marriage_divorce_data['Divorces_per_1000'].values

#import matplotlib and numpy
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# values = [marriages_per_capita, divorces_per_capita]

plt.figure(figsize=(5,5))

plt.bar(years, marriages_per_capita,divorces_per_capita )
plt.bar(years + 1,
        marriages_per_capita,
        color='blue',
        edgecolor='none',
        width=1,
        align='center',
        label='Marriages %')

plt.bar(years - 1,
        divorces_per_capita,
        color = 'orange',
        edgecolor='none',
        width=1,
        align='center',
        label='Divorces %')

#plt.xticks(years, [str(year) for year in years])

plt.legend()
;
# Out:
# ''

# %% [markdown]
# # Exercise 3
#
# Create a horizontal bar chart that compares the deadliest actors in Hollywood. Sort the actors by their kill count and label each bar with the corresponding actor's name.
#
# Don't forget to label your axes!
#
# For reference, here's the raw data:

# %%
import pandas as pd

hollywood_actor_kills = pd.read_csv('data/actor_kill_counts.csv')
actor_names = hollywood_actor_kills['Actor'].values
# print(actor_names)
kill_counts = hollywood_actor_kills['Count'].values
# print(kill_counts)


#import matplotlib and numpy
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

category_values = pd.DataFrame({'categories':actor_names, 'values':kill_counts})
# print(category_values)
# print(type(category_values))

category_values.sort_values('values', ascending=False, inplace=True)
# print(category_values)

hollywood_actor_kills = category_values['categories'].values
kill_counts  = category_values['values'].values

plt.figure()
#use negatize to change the position of the categories
plt.barh(-np.arange(len(actor_names)), kill_counts)
plt.yticks(-np.arange(len(actor_names)),['Actor: {}'.format(x) for x in actor_names])


plt.legend()
;
# Out:
# C:\Users\melios\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:531: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
# ''

# %% [markdown]
# # Exercise 4
#
# Create a pie chart showing the fraction of all Roman Emperors that were assassinated.
#
# Make sure that the pie chart is an even circle, labels the categories, and shows the percentage breakdown of the categories.

# %%
import pandas as pd

#import data 
roman_emperors = pd.read_csv('data/roman-emperor-reigns.csv')
assassinated_emperors = roman_emperors[
    roman_emperors['Cause_of_Death'].apply(lambda x: 'assassinated' in x.lower())]

number_assassinated = len(assassinated_emperors)
other_deaths = len(roman_emperors) - number_assassinated

#import matplotlib and numpy
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

counts = [number_assassinated, other_deaths]

plt.figure(figsize=(8,8))
plt.pie(counts,
        colors=['blue','orange'],
        labels=['Emperor assassinated','Other death'],
        startangle=90,
        autopct='%1.1f%%')

plt.legend()
;
# Out:
# ''

# %% [markdown]
# # Exercise 5
#
# Create a scatter plot showing the relationship between the total revenue earned by arcades and the number of Computer Science PhDs awarded in the U.S. between 2000 and 2009.
#
# Don't forget to label your axes!
#
# **Bonus:** Color each dot according to its year.

# %%
import pandas as pd

arcade_revenue_cs_doctorates = pd.read_csv('data/arcade-revenue-vs-cs-doctorates.csv')

arcade_revenue = arcade_revenue_cs_doctorates['Total Arcade Revenue (billions)'].values
cs_doctorates_awarded = arcade_revenue_cs_doctorates[
    'Computer Science Doctorates Awarded (US)'].values
# print(arcade_revenue)
# print(cs_doctorates_awarded)



# category_values = pd.DataFrame({'categories':actor_names, 'values':kill_counts})
# # print(category_values)
# # print(type(category_values))

# category_values.sort_values('values', ascending=False, inplace=True)
# # print(category_values)

# arcade_revenue = category_values['categories'].values
# cs_doctorates_awarded = category_values['values'].values


#import matplotlib and numpy
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

plt.figure()
plt.scatter(cs_doctorates_awarded,
            arcade_revenue,
            c='red',
            s=50,
            marker='s',
            edgecolors='none')

plt.legend()
;
# Out:
# [ 1.196  1.176  1.269  1.24   1.307  1.435  1.601  1.654  1.803  1.734]
# [ 861  830  809  867  948 1129 1453 1656 1787 1611]
# C:\Users\melios\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:531: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
# ''
